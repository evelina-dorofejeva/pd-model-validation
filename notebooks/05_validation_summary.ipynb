# %%
# This analysis reviews the provided PD model outputs using historical data.
# Visual analysis is provided separately to support qualitative assessment.

# The goal of this task is to:
# - check basic data quality,
# - understand missing values,
# - verify PD and PD pool logic,
# - assess whether PD estimates reflect observed default risk.

# The analysis is done at a basic level and focuses on understanding the model output and its consistency.

# %%
# In the analysis were used following datasets:
# - dat_scoring - model outputs (PD, PD_POOL, default flag)
# - dat_arrangement - additional financial information
# - dat_obligor - customer characteristics
# - par_pools - PD pool threshold definitions

# %%
# Data quality checks showed:
# - A small share of PD values is missing.
# - DPD values are missing for a large part of observations.
# - Duplicates by (YEAR, AR_ID) were found in dat_arrangement. In such cases, the most informative record was kept.

# %%
# The impact of missing values was analysed:
# - Records with missing DPD show lower default rates.
# - Missing PD values have a similar default rate compared to available PD values.
# - Missing values are not random, but their impact on overall portfolio risk appears limited.

# %%
# The model shows clear risk separation:
# - Higher PD pools show higher default rates, indicating clear risk separation.
# - Pool 5 represents the highest risk group.

# Default rates increase in 2024 across most PD pools, suggesting higher portfolio risk in that year.

# %%
# Final Conclusion:
# - The model separates clients by risk level
# - PD pools are consistent with observed defaults
# - Missing values do not critically bias results
# - Risk levels increase in 2024
